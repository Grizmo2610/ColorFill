# %%
import os

path = "labcolor"

if os.path.isdir(path):
    print("Đây là thư mục")
elif os.path.isfile(path):
    print("Đây là file")
else:
    print("Không tồn tại")
# Out:
# Đây là file

# %%
import os
